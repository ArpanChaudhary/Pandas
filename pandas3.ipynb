# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpanChaudhary/Pandas/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PANDAS

# %%
## Import pandas and NumPy libraries

# %%
import numpy as np
import pandas as pd

# %%
## create a dataframe in a different way

# %%
matrix_data = np.matrix('22,66,140;42,70,148;30,62,125;35,68,160;25,62,152')

row = ['Raju','Pandey','Srini','Sunil','Ashok']

column = ['Age','Height','Weight']

# %%
df = pd.DataFrame(data = matrix_data, index = row, columns = column)

print(df)
# Out:
#         Age  Height  Weight
# Raju     22      66     140
# Pandey   42      70     148
# Srini    30      62     125
# Sunil    35      68     160
# Ashok    25      62     152

# %%
df['Height']
# Out:
# Raju      66
# Pandey    70
# Srini     62
# Sunil     68
# Ashok     62
# Name: Height, dtype: int64

# %%
df['Age']
# Out:
# Raju      22
# Pandey    42
# Srini     30
# Sunil     35
# Ashok     25
# Name: Age, dtype: int64

# %%
df['Weight']
# Out:
# Raju      140
# Pandey    148
# Srini     125
# Sunil     160
# Ashok     152
# Name: Weight, dtype: int64

# %%
only_height_weight = df[['Height','Weight']]

only_height_weight
# Out:
#         Height  Weight
# Raju        66     140
# Pandey      70     148
# Srini       62     125
# Sunil       68     160
# Ashok       62     152

# %%
only_age_weight = df[['Age','Weight']]

only_age_weight
# Out:
#         Age  Weight
# Raju     22     140
# Pandey   42     148
# Srini    30     125
# Sunil    35     160
# Ashok    25     152

# %%
## use 'loc' function to locate the element based on the label name

# %%
df.loc['Raju']
# Out:
# Age        22
# Height     66
# Weight    140
# Name: Raju, dtype: int64

# %%
df.loc['Srini']
# Out:
# Age        30
# Height     62
# Weight    125
# Name: Srini, dtype: int64

# %%
## use 'iloc' function to locate the element based on index

# %%
df.iloc[3]
# Out:
# Age        35
# Height     68
# Weight    160
# Name: Sunil, dtype: int64

# %%
df.iloc[4]
# Out:
# Age        25
# Height     62
# Weight    152
# Name: Ashok, dtype: int64

# %%
df
# Out:
#         Age  Height  Weight
# Raju     22      66     140
# Pandey   42      70     148
# Srini    30      62     125
# Sunil    35      68     160
# Ashok    25      62     152

# %%
## locate the element based on label name with its column values

# %%
df.loc['Raju','Age']
# Out:
# 22

# %%
df.loc['Pandey','Weight']
# Out:
# 148

# %%
df.loc['Ashok',['Age','Weight']]
# Out:
# Age        25
# Weight    152
# Name: Ashok, dtype: int64

# %%
df.loc['Srini',['Age','Height','Weight']]
# Out:
# Age        30
# Height     62
# Weight    125
# Name: Srini, dtype: int64

# %%
df.loc[['Srini','Sunil'],['Age','Weight']]
# Out:
#        Age  Weight
# Srini   30     125
# Sunil   35     160

# %%
df.loc['Raju',['Age','Height']]
# Out:
# Age       22
# Height    66
# Name: Raju, dtype: int64

# %%
df
# Out:
#         Age  Height  Weight
# Raju     22      66     140
# Pandey   42      70     148
# Srini    30      62     125
# Sunil    35      68     160
# Ashok    25      62     152

# %%
## fetching element based on condition

# %%
df[df['Age']>30]
# Out:
#         Age  Height  Weight
# Pandey   42      70     148
# Sunil    35      68     160

# %%
df[df['Age']<30]
# Out:
#        Age  Height  Weight
# Raju    22      66     140
# Ashok   25      62     152

# %%
df[df['Age']==30]
# Out:
#        Age  Height  Weight
# Srini   30      62     125

# %%
df['Height']>60
# Out:
# Raju      True
# Pandey    True
# Srini     True
# Sunil     True
# Ashok     True
# Name: Height, dtype: bool

# %%
df[df['Height']>60]
# Out:
#         Age  Height  Weight
# Raju     22      66     140
# Pandey   42      70     148
# Srini    30      62     125
# Sunil    35      68     160
# Ashok    25      62     152

# %%
df[df['Height']<50]
# Out:
# Empty DataFrame
# Columns: [Age, Height, Weight]
# Index: []

# %%
booldf1 = df['Height']>65
booldf2 = df['Weight']>145

# %%
print(df[(booldf1) & (booldf2)])
# Out:
#         Age  Height  Weight
# Pandey   42      70     148
# Sunil    35      68     160

# %%
df[booldf1][['Age','Weight']]
# Out:
#         Age  Weight
# Raju     22     140
# Pandey   42     148
# Sunil    35     160

# %%
selected_canditates = df[booldf1][['Age','Weight']]

# %%
selected_canditates
# Out:
#         Age  Weight
# Raju     22     140
# Pandey   42     148
# Sunil    35     160

# %%
df
# Out:
#         Age  Height  Weight
# Raju     22      66     140
# Pandey   42      70     148
# Srini    30      62     125
# Sunil    35      68     160
# Ashok    25      62     152

# %%
df.reset_index()
# Out:
#     index  Age  Height  Weight
# 0    Raju   22      66     140
# 1  Pandey   42      70     148
# 2   Srini   30      62     125
# 3   Sunil   35      68     160
# 4   Ashok   25      62     152

# %%
df = df[df['Age']<35]
df
# Out:
#        Age  Height  Weight
# Raju    22      66     140
# Srini   30      62     125
# Ashok   25      62     152

# %%
df.reset_index(drop = True)
# Out:
#    Age  Height  Weight
# 0   22      66     140
# 1   30      62     125
# 2   25      62     152

# %%
df['Profession'] = "Student Engineer Teacher".split()
df
# Out:
# <ipython-input-42-c7c541f33f65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profession'] = "Student Engineer Teacher".split()
#        Age  Height  Weight Profession
# Raju    22      66     140    Student
# Srini   30      62     125   Engineer
# Ashok   25      62     152    Teacher

# %%
df.set_index('Profession')
# Out:
#             Age  Height  Weight
# Profession
# Student      22      66     140
# Engineer     30      62     125
# Teacher      25      62     152

# %%
df['Country'] = "India US Australia".split()
# Out:
# <ipython-input-44-c5805c2ddc4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = "India US Australia".split()

# %%
df
# Out:
#        Age  Height  Weight Profession    Country
# Raju    22      66     140    Student      India
# Srini   30      62     125   Engineer         US
# Ashok   25      62     152    Teacher  Australia

# %%
df.set_index('Country')
# Out:
#            Age  Height  Weight Profession
# Country
# India       22      66     140    Student
# US          30      62     125   Engineer
# Australia   25      62     152    Teacher
